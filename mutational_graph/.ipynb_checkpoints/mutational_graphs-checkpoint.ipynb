# %%
from UsefullFunctions import *

# % of alt alleles to add amino acide label
def_min_val_AAlabel(15)

create_nucsub_AAname("Mut_Nuc_AA_ORF.dic")

# %%
namelist=['Delta','noCanada.AY.27','Canada.AY.27']
pathlist=["/lustre03/project/6009524/shared/covid-19/GISAID/2021-09-27/msa_0927."+i+".data.var" for i in namelist]
namelist=[i.replace("Canada.","Canada\n") for i in namelist]
namelist=[i.replace("no","no\n") for i in namelist]
percentmin=10

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29768]

bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
trypath="/lustre03/project/6009524/shared/covid-19/Recombinaison/Sally_doubleDEL/tryrecomb"
namelist=['Delta','Alpha']
pathlist=["/lustre03/project/6009524/shared/covid-19/GISAID/2021-09-27/msa_0927."+i+".data.var" for i in namelist]
id="1846203"
namelist.append("EPI_ISL\n"+id)
pathlist.append(trypath+"/EPI_ISL_"+id+".data.var")
percentmin=80

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29768]
print(len(poslist))
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))
# Out:
# [208, 239, 911, 3035, 3265, 4179, 5386, 5984, 6400, 6952, 7122, 8984, 9051, 10027, 11199, 11330, 14406, 14674, 15277, 15449, 16174, 16464, 19218, 21616, 22915, 22993, 23061, 23269, 23401, 23602, 23707, 24408, 24504, 24912, 25467, 26765, 27636, 27750, 27872, 27970, 28046, 28109, 28278, 28279, 28280, 28459, 28879, 28880, 28881, 28882, 28914, 28975, 29400, 29740]

# %%
namelist=['Alpha','Beta','Gamma','Delta','Eta','Iota','Kappa','Lambda','Mu']
haplist=['Alpha','B.1.351','P.1','Delta','B.1.525','B.1.526','B.1.617.1','C.37','B.1.621']
#namelist=['Alpha','Beta','Gamma','Delta']
#haplist=['Alpha','B.1.351','P.1','Delta']
pathlist=[GISAIDfile(i) for i in haplist]
percentmin=60

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin)
print(len(poslist))
poslist=getpositions(tablelist,percentmin,True)
print(len(poslist))
poslist=[i for i in poslist if i>50 and i<29768]
print(len(poslist))
#poslist=poslist[13:21]
#pathlist=pathlist[3:5]

bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=['Alpha','Beta','Gamma','Delta','Eta','Iota','Kappa','Lambda','Mu']
haplist=['Alpha','B.1.351','P.1','Delta','B.1.525','B.1.526','B.1.617.1','C.37','B.1.621']
namelist=['Alpha','Gamma','Delta']
haplist=['Alpha','P.1','Delta']
pathlist=[GISAIDfile(i) for i in haplist]

path_allprot="/lustre03/project/6009524/shared/covid-19/Recombinaison/allprot_21-09-19/"

pathlist.append(path_allprot+"both.data.var")
namelist.append("DD")
#for c in ["Turkey","USA","Italy","Canada","Canada_noGamma"]:
for c in ["Canada","Canada_noGamma"]:
    pathlist.append(path_allprot+"both."+c+".data.var")
    namelist.append("DD\n"+c)

percentmin=60

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin,True)
poslist=[i for i in poslist if (i>50 and i<29768 and i not in range(11288,11295)) or i==29833]
print(len(poslist))
#poslist=poslist[13:21]
#pathlist=pathlist[3:5]

bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=['Alpha','Beta','Gamma','Delta','Eta','Iota','Lambda','Mu']
haplist=['Alpha','B.1.351','P.1','Delta','B.1.525','B.1.526','C.37','B.1.621']
namelist=['Alpha','Eta','Iota','Kappa','Lambda','Mu']
haplist=['Alpha','B.1.525','B.1.526','B.1.617.1','C.37','B.1.621']
pathlist=[GISAIDfile(i) for i in haplist]

path_allprot="/lustre03/project/6009524/shared/covid-19/Recombinaison/allprot_21-09-19/"

#pathlist.append(path_allprot+"both.data.var")
#namelist.append("DD")
#for c in ["Turkey","USA","Italy","Canada","Canada_noGamma"]:
for c in ["USA","Minnesota"]:
    pathlist.append(path_allprot+"both."+c+".data.var")
    namelist.append("DD\n"+c)

percentmin=25

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if (i>50 and i<29768) or i==29833]
print(len(poslist))
#poslist=poslist[13:21]
#pathlist=pathlist[3:5]

bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=['B.1.617.2','Delta']
pathlist=[GISAIDfile(i) for i in namelist]


percentmin=10
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["VIII", "V", "X", "XI", "XV"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/paper_final."+i+".data.var")

percentmin=10
    
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["B.1.617.2","B.1.1.7"]
pathlist=[]
for i in namelist:
    pathlist.append(GISAIDfile(i))
pathlist.append("/lustre03/project/6009524/shared/covid-19/Recombinaison/allprot_sept_2021/nuc132_from172.data.var")
pathlist.append("/lustre03/project/6009524/shared/covid-19/Recombinaison/allprot_sept_2021/nuc132_from172_28881T.data.var")
pathlist.append("/lustre03/project/6009524/shared/covid-19/Recombinaison/allprot_sept_2021/nuc132_from172_28881A.data.var")
pathlist.append("/lustre03/project/6009524/shared/covid-19/Recombinaison/allprot_sept_2021/nuc132_from172_28881G.data.var")
namelist=["Delta","Alpha","DD","DD_28881T","DD_28881A","DD_28881G"]
percentmin=70
    
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["I","II"]
pathlist=[]
for i in namelist:
    pathlist.append(GISAIDfile(i))
    pathlist.append("/lustre03/project/6009524/shared/covid-19/Recombinaison/small_raphGraph_JC/list."+i+".data.var")
namelist=["I","sub-I","II","sub-II"]
    
percentmin=20
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["II_c3", "II_c2", "II_c1"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/MS-PHATE/paper_final."+i+".data.var")
namelist=["C3", "C2", "C1"]
percentmin=10

tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["XVII", "XIII"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/paper_final."+i+".data.var")
#namelist=["C3", "C2", "C1"]
percentmin=10

tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["II_c3", "II_c2", "II_c1"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/MS-PHATE/paper_final."+i+".data.var")
namelist=["C3", "C2", "C1"]
percentmin=10

tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["III_XIV", "III", "XIV"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/MS-PHATE/paper_final."+i+".data.var")

percentmin=10
    
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["XV_c0", "XV_c1", "XV_c2", "XV_c3", "XV_c4", "XV_c5", "XV_c6", "XV_c7", "XV_c8"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/MS-PHATE/paper_final."+i+".data.var")

namelist=[i.replace("XV_c","C") for i in namelist]
percentmin=50

    
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["III_c1","III_c2","III_c3", "III_c4", "III_c5", "III_c6"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/MS-PHATE/paper_final."+i+".data.var")

percentmin=25
    
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin)
poslist=[i for i in poslist if i>50 and i<29853]
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["JessieXV_"+str(i) for i in range(1,9)]
namelist.append("paper_final.XV")
pathlist=[]
n=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/"+i+".data.var")
    n.append(i.replace("paper.","").replace("_","\n").replace(".","\n"))
namelist=n    
percentmin=10

tablelist=openfiles(pathlist)
poslist=getpositions(tablelist,percentmin,addmissing=False)
print(len(poslist))
poslist=[i for i in poslist if i>50 and i<29853]
print(len(poslist))
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["VIII","III","XIV","JulieJuly20.VIII","JulieJuly20.III","JulieJuly20.XIV"]
pathlist=[]
n=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/paper_final."+i+".data.var")
    n.append(i.replace(".","\n"))
namelist=n
percentmin=1
    
tablelist=openfiles(pathlist)
poslist=getpositions(tablelist[3:],percentmin,addmissing=True)
poslist=[i for i in poslist if i>50 and i<29853]
print(len(poslist))
#print(poslist)
bighist(tablelist,poslist,namelist,mytitle="min = "+str(percentmin))

# %%
namelist=["VIII","V","X","XI","XV"]
pathlist=[]
for i in namelist:
    pathlist.append("/lustre03/project/6009524/shared/covid-19/database/data/inter/2021_01_20_imputed_hapV3/dataformat/paper_final."+i+".data.var")

percentmin=10

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin)

poslist=[i for i in poslist if i>50 and i<29875]

#print(poslist)
bighist(tablelist,
        poslist,
        namelist,
        mytitle="min = "+str(percentmin))

# %%
def getprimerpos(i):
    p=np.unique([int(k[0:-3]) for k,v in nucsub_AAname.items() if v=="p"+str(i)])
    return p

hapist=["B.1.1.317","B.1.1.29","B.1.1.214","B.1.1.1","B.1.160","P.1","A.2.5.2","A.2.5","B.1.351"]
hapist=["B.1.160"]
pathlist=[]
namelist=[]
for i in hapist:
    pathlist.append("/genfs/projects/COVID_JH/per_run/explore_nanopore/nanopore."+i+".data.var")
    namelist.append("LSPQ\n"+i)
    pathlist.append(GISAIDfile(i))
    namelist.append("GISAID\n"+i)

tables=openfiles(pathlist)
positions=getpositions(tables,5)
primer=getprimerpos(18)
pmin=primer[0]-160
pmax=primer[-1]+140
p1=[i for i in positions if (i>pmin and i<pmax)]
p2=list(range(pmin,pmax,10))
#p3=list(range(21980,21990))
p=np.unique(p1+p2+p3)
p.sort()
bighist(tables,p,namelist)

# %%
pathlist=["/lustre03/project/6009524/shared/covid-19/Colcorona/data_format/final.all.data.var",
          "/lustre03/project/6009524/shared/covid-19/Colcorona/data_format/final.B.1.160.data.var",
          "/lustre03/project/6009524/shared/covid-19/Colcorona/data_format/final.B.1.1.157.data.var",
          "/lustre03/project/6009524/shared/covid-19/Colcorona/data_format/final.B.1.1.176.data.var",
          "/lustre03/project/6009524/shared/covid-19/Colcorona/data_format/final.B.1.147.data.var"]
namelist=["all",
         "B.1.160",
         "B.1.1.157",
         "B.1.1.176",
         "B.1.147"]
bighist(pathlist,10,namelist)

# %%
#try with B.1.160 data from colcorona vs gisaid
pathlist=["/lustre03/project/6009524/shared/covid-19/GISAID/2021-01-20/Analysis_Combined/resplit/B.1.160/B.1.160.data.var",
          "/lustre03/project/6009524/shared/covid-19/Colcorona/Consensus_noHost_complete_unfiltered_Colco_LSPQ/t0.75/msa/phylotree/freq/B.1.160/B.1.160.data.var"]
namelist=["GISAID","Colcorona"]
n=2
percentmin=10

tablelist=openfiles(pathlist)

poslist=getpositions(tablelist,percentmin)

poslist=[i for i in poslist if i>50 and i<29875]

#print(poslist)
bighist(tablelist,
        poslist,
        namelist,
        mytitle="min = "+str(percentmin))

# %%
pathlist=["/scratch/poujolra/check_nex/EPI_ISL_408487.data.var",
          "/scratch/poujolra/check_nex/EPI_ISL_417413.data.var",
          "/scratch/poujolra/check_nex/EPI_ISL_479662.data.var",
          "/scratch/poujolra/check_nex/EPI_ISL_454554.data.var",
          "/scratch/poujolra/check_nex/EPI_ISL_728330.data.var",
          "/scratch/poujolra/check_nex/EPI_ISL_753698.data.var"]
namelist=["408487","417413","479662","454554","728330","753698"]
n=6
bighist(pathlist[:n],90,namelist[:n])

# %%
#Carmen Virologival figure

p="/lustre03/project/6009524/shared/covid-19/GISAID/2021-05-01/msa_0501.Carmen_noQC."
namesGISAID=["A","A.2.5","A.2.5.1","A.2.5.2","A.23.1","A.21","A.27"]
filesGISAID=[p+i+".data.var" for i in namesGISAID]
filesGISAID.insert(1,"/genfs/projects/COVID_JH/per_run/runs_2021-05-04_LSPQReport/analyses/final.CarmenList.A.data.var")
filesGISAID.insert(5,"/genfs/projects/COVID_JH/per_run/runs_2021-05-04_LSPQReport/analyses/final.CarmenList.A.2.5.data.var")

namesGISAID=["GISAID\n"+i for i in namesGISAID]

namesGISAID.insert(1,"LSPQ\nA")
namesGISAID.insert(5,"LSPQ\nA.2.5.2")

bighist(filesGISAID,90,namesGISAID,False)

lspqCarmenpath="/genfs/projects/COVID_JH/per_run/runs_2021-05-04_LSPQReport/analyses/final.CarmenList.",

#namesLSPQ=["CarmenList"]
#filesLSPQ=[path_LSPQ+"/final."+i+".data.var" for i in namesLSPQ]
#names=namesGISAID+namesLSPQ
#files=filesGISAID+filesLSPQ

#names=["GISAID","LSPQ"]
#bighist(files,30,names,False)

# %%
#Martin Smith stuff

pathMS="/lustre03/project/6009524/shared/covid-19/RhinoNet/small_association4MartinSmith"
names=["IIa","IIb","III"]
files=[]
for n in names:
    files.append(pathMS+"/"+n+".var")
bighist(files,10,names)
EPI_ISL_417413.data.freq  EPI_ISL_479549.data.freq  EPI_ISL_512061.data.freq  EPI_ISL_570305.data.freq  EPI_ISL_712018.data.freq  EPI_ISL_753698.data.freq  EPI_ISL_812862.data.freq
EPI_ISL_408483.data.freq  EPI_ISL_427243.data.freq  EPI_ISL_479662.data.freq  EPI_ISL_514285.data.freq  EPI_ISL_570609.data.freq  EPI_ISL_728204.data.freq  EPI_ISL_755956.data.freq  EPI_ISL_814096.data.freq
EPI_ISL_408487.data.freq  EPI_ISL_454554.data.freq  EPI_ISL_483719.data.freq  EPI_ISL_527871.data.freq  EPI_ISL_577666.data.freq  EPI_ISL_728330.data.freq  EPI_ISL_803950.data.freq  EPI_ISL_825403.data.freq
EPI_ISL_415618.data.freq  EPI_ISL_475586.data.freq  EPI_ISL_485957.data.freq  EPI_ISL_528540.data.freq  EPI_ISL_577699.data.freq  EPI_ISL_737283.data.freq  EPI_ISL_812832.data.freq  msa_0526_final.data.freq

# %%
minimum=80
i="B.1.1.28"
file="msa_0425."+i+".data.var"
t=pd.read_csv(file,sep="\t")
n_min=math.ceil(minimum/100*sum(t.iloc[0][["A","C","G","T","."]]))
poslist=[]
poslist+=list(t[(t["REF"]=="A") & ((t["C"]>=n_min) | (t["G"]>=n_min) | (t["T"]>=n_min))].index)
poslist+=list(t[(t["REF"]=="C") & ((t["A"]>=n_min) | (t["G"]>=n_min) | (t["T"]>=n_min))].index)
poslist+=list(t[(t["REF"]=="G") & ((t["C"]>=n_min) | (t["A"]>=n_min) | (t["T"]>=n_min))].index)
poslist+=list(t[(t["REF"]=="T") & ((t["C"]>=n_min) | (t["G"]>=n_min) | (t["A"]>=n_min))].index)

# %%
nicknames=["Brazil","Qc","South-Africa","California","Niger","UK"]
#figure LSPQ CARMEN
l=["B.1.1.28","B.1.160","B.1.351","B.1.429","B.1.525","B.1.1.7"]
names=[]
files=[]
for i in l:
    names.append("GISAID\n"+i)
    names.append("LSPQ\n"+i)
    files.append(GISAIDfile(i))
    files.append(LSPQfile(i))

print (names)
print (files)
bighist(files,90,names,False)

# %%
Indian_names=["B.1.617","B.1.617.1","B.1.617.2","B.1.617.3"]
Indian_files=[path_GISAID+"/msa_0501."+i+".data.var" for i in Indian_names]

bighist(Indian_files,30,Indian_names,True)

# %%
#figure GISAID CARMEN
namesGISAID=["A","A.2.5","A.2.5.1","A.2.5.2","A.23.1","A.21","A.27"]
filesGISAID=[path_GISAID+"/msa_0501.Carmen_noQC."+i+".data.var" for i in namesGISAID]
namesLSPQ=[]
filesLSPQ=[path_LSPQ+"/final."+i+".data.var" for i in namesLSPQ]
names=namesGISAID+namesLSPQ
files=filesGISAID+filesLSPQ

bighist(files,90,names,False)

# %%
#figure LSPQ CARMEN
names=["GISAID\nA","LSPQ\nA","GISAID\nA.2.5","LSPQ\nA.2.5"]
files=[GISAIDfile("A"),LSPQfile("A"),GISAIDfile("A.2.5"),LSPQfile("A.2.5")]

bighist(files,90,names,False)

# %%
namesGISAID=["B.1.526","B.1.526.1","B.1.526.2"]
filesGISAID=[path_GISAID+"/msa_0501."+i+".data.var" for i in namesGISAID]
namesLSPQ=[]
filesLSPQ=[path_LSPQ+"/final."+i+".data.var" for i in namesLSPQ]
names=namesGISAID+namesLSPQ
files=filesGISAID+filesLSPQ

bighist(files,50,names,False)

# %%
Indian_files=["B.1.617","B.1.617.1","B.1.617.2","B.1.617.3","XXXVIII"]
n=["B.1.617","B.1.617.1","B.1.617.2","B.1.617.3","XXXVIII"]
bighist(Indian_files,30)

# %%
strangehaps=["TCYATTCTCGCCGAGGKGTGGG","TCCATTCTCGCCGAGGCGTGGG","TCTATTCTCGCCGAGGCGTGGG","TCTATTCTCGCCGAGGGGTGGG","TCCATTCTCGCCGAGGGGTGGG"]
n=["YK","CC","TC","TG","CG III"]
bighist(strangehaps,30,n)

# %%
UK_brazil_files=["XV","B.1.1.7","B.1.1.28"]
nicknames=["","UK","Brazil"]
bighist(UK_brazil_files,5,nicknames)

# %%
SA=["XVII","B.1.351"]
bighist(SA,10)

# %%
strangeQuebec=["XXXVI","VII","XII","CCCACTTCTGCCGAGGGGCGGG"]
nicknames=["XXXVI","VII","XII","XII.2"]
bighist(strangeQuebec,30,nicknames)
